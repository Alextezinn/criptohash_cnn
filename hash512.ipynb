# %%
import time
import json
import random
import base64
from pathlib import Path
import os

import torch
import torchvision.transforms as transforms
import torch.nn.functional as F
import cv2
import PIL.Image
import numpy as np
from torchvision import models
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import requests
import numpy as np

# %%
class ImageEncoder(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.resnet = models.resnet18(pretrained=True)
        self.encoder = torch.nn.Sequential(
            *list(self.resnet.children())[:-2],
            torch.nn.AdaptiveAvgPool2d(1),
            torch.nn.Flatten()
        )

    def forward(self, x):
        x = self.encoder(x)
        return x

# %%
def preprocess(image):
  device = torch.device('cuda')
  mean = torch.Tensor([0.485, 0.456, 0.406]).cuda()
  std = torch.Tensor([0.229, 0.224, 0.225]).cuda()

  transform = transforms.Compose([
        #transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
  ])

  image_transform = transform(image)

  return torch.Tensor(image_transform).unsqueeze(0).to(device)

# %%
def matching_hash_two_pictures(tensor_one, tensor_two):
    count_match = 0

    for i in range(len(tensor_one)):
        if tensor_one[i] == tensor_two[i]:
            count_match += 1

    print(f"Совпадение соответствующих feature map двух картинок = {100 * (count_match/len(tensor_one))} %")

# %%
def compare_two_pictures(path_image_one, path_image_two, model, change_one_pixel=False):
    image = Image.open(path_image_one).convert('RGB')
    preprocessed = preprocess(image)
    output_image_one = model(preprocessed)
    output_image_one = output_image_one.detach().cpu().numpy()

    print(output_image_one.shape)

    image = Image.open(path_image_two).convert('RGB')
    preprocessed = preprocess(image)

    if change_one_pixel:
        preprocessed[0][0][0][0] = 0

    output_image_two = model(preprocessed)
    output_image_two = output_image_two.detach().cpu().numpy()
    print(output_image_two.shape)

    cos = torch.nn.CosineSimilarity(dim=1)
    # print(torch.Tensor(output_image_one))
    # print(torch.Tensor(output_image_one).shape)
    cos = cos(torch.Tensor(output_image_one), torch.Tensor(output_image_two))

    # print(output_image_one[0].shape)
    # print(output_image_two[0].shape)

    print(f"Косинусное расстояние между двумя картинками равно : {cos[0]}")
    matching_hash_two_pictures(output_image_one[0], output_image_two[0])

# %%
def preprocess_other(image):
  device = torch.device('cuda')
  mean = torch.Tensor([0.485, 0.456, 0.406]).cuda()
  std = torch.Tensor([0.229, 0.224, 0.225]).cuda()

  transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
  ])

  image_transform = transform(image)

  return torch.Tensor(image_transform).unsqueeze(0).to(device)

# %%
def compare_two_pictures_other(path_image_one, path_image_two, model, change_one_pixel=False):
    image = Image.open(path_image_one).convert('RGB')
    preprocessed = preprocess_other(image)
    output_image_one = model(preprocessed)
    output_image_one = output_image_one.detach().cpu().numpy()

    #image = torch.Tensor(np.array(Image.open(path_image_two).convert('RGB'))).unsqueeze(0).to(device)
    image = Image.open(path_image_two).convert('RGB')
    preprocessed = preprocess(image)
    # mean = torch.Tensor([0.485, 0.456, 0.406]).cuda()
    # std = torch.Tensor([0.229, 0.224, 0.225]).cuda()

    # transform = transforms.Compose([
    #     transforms.ToTensor(),
    #     #transforms.Normalize(mean, std)
    # ])

    # image = transform(image)
    # image = torch.Tensor(image).unsqueeze(0).to(device)

    if change_one_pixel:
        preprocessed[0][0][0][0] = 0

    output_image_two = model(preprocessed)
    output_image_two = output_image_two.detach().cpu().numpy()

    cos = torch.nn.CosineSimilarity(dim=1)
    # print(torch.Tensor(output_image_one))
    # print(torch.Tensor(output_image_one).shape)
    cos = cos(torch.Tensor(output_image_one), torch.Tensor(output_image_two))

    # print(output_image_one[0].shape)
    # print(output_image_two[0].shape)

    print(f"Косинусное расстояние между двумя картинками равно : {cos[0]}")
    matching_hash_two_pictures(output_image_one[0], output_image_two[0])

# %%
def compare_two_pictures_other1(path_image_one, path_image_two, model, change_one_pixel=False):
    image = Image.open(path_image_one).convert('RGB')
    preprocessed = preprocess_other(image)
    output_image_one = model(preprocessed)
    output_image_one = output_image_one.detach().cpu().numpy()

    #image = torch.Tensor(np.array(Image.open(path_image_two).convert('RGB'))).unsqueeze(0).to(device)
    image = Image.open(path_image_two).convert('RGB')
    preprocessed = preprocess_other(image)
    # mean = torch.Tensor([0.485, 0.456, 0.406]).cuda()
    # std = torch.Tensor([0.229, 0.224, 0.225]).cuda()

    # transform = transforms.Compose([
    #     transforms.ToTensor(),
    #     #transforms.Normalize(mean, std)
    # ])

    # image = transform(image)
    # image = torch.Tensor(image).unsqueeze(0).to(device)

    if change_one_pixel:
        preprocessed[0][0][0][0] = 0

    output_image_two = model(preprocessed)
    output_image_two = output_image_two.detach().cpu().numpy()

    cos = torch.nn.CosineSimilarity(dim=1)
    # print(torch.Tensor(output_image_one))
    # print(torch.Tensor(output_image_one).shape)
    cos = cos(torch.Tensor(output_image_one), torch.Tensor(output_image_two))

    # print(output_image_one[0].shape)
    # print(output_image_two[0].shape)

    print(f"Косинусное расстояние между двумя картинками равно : {cos[0]}")
    matching_hash_two_pictures(output_image_one[0], output_image_two[0])

# %%
model = ImageEncoder()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.eval()
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 197MB/s]

# %%
# тестирование на 100 картинках

# %%
# !git clone https://github.com/Alextezinn/hash512.git
# Out:
# Cloning into 'hash512'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 105 (delta 0), reused 105 (delta 0), pack-reused 0
# Receiving objects: 100% (105/105), 1.44 MiB | 10.79 MiB/s, done.

# %%
def new_matching_hash_two_pictures(tensor_one, tensor_two):
    count_match = 0

    for i in range(len(tensor_one)):
        if tensor_one[i] == tensor_two[i]:
            count_match += 1
    print(count_match)
    print(f"Совпадение соответствующих feature map двух картинок = {100 * (count_match/len(tensor_one))} %")
    return 100 * (count_match/len(tensor_one))

# %%
def compare_two_pictures_px(path_image_one, path_image_two, model, count_px):
    image = Image.open(path_image_one).convert('RGB')
    preprocessed = preprocess(image)
    output_image_one = model(preprocessed)
    output_image_one = output_image_one.detach().cpu().numpy()

    print(output_image_one.shape)

    image = Image.open(path_image_two).convert('RGB')
    preprocessed = preprocess(image)

    # shape [1, 3, 224, 224]

    for i in range(count_px):
        preprocessed[0][0][i*10][i*10] = 0
        preprocessed[0][1][i*10][i*10] = 0
        preprocessed[0][2][i*10][i*10] = 0

    output_image_two = model(preprocessed)
    output_image_two = output_image_two.detach().cpu().numpy()
    print(output_image_two.shape)

    cos = torch.nn.CosineSimilarity(dim=1)
    # print(torch.Tensor(output_image_one))
    # print(torch.Tensor(output_image_one).shape)
    cos = cos(torch.Tensor(output_image_one), torch.Tensor(output_image_two))

    # print(output_image_one[0].shape)
    # print(output_image_two[0].shape)

    print(f"Косинусное расстояние между двумя картинками равно : {cos[0]}")
    return cos[0], new_matching_hash_two_pictures(output_image_one[0], output_image_two[0])

# %%
hash = 0
cos_ = 0
path = Path("/content/hash512/images_100")
for filename in os.listdir(path):
    a, b = compare_two_pictures_px(path / filename, path / filename, model, 1)
    cos_ += float(a)
    hash += b

print(hash / 100)
print(cos_ / 100)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9999976754188538
# 81
# Совпадение соответствующих feature map двух картинок = 15.8203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9
625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9975577592849731
# 32
# Совпадение соответствующих feature map двух картинок = 6.25 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9997777938842773
# 92
# Совпадение соответствующих feature map двух картинок = 17.96875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9971144199371338
# 31
# Совпадение соответствующих feature map двух картинок = 6.0546875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9981017112731934
# 16
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994269609451294
# 41
# Совпадение соответствующих feature map двух картинок = 8.0078125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9848640561103821
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9888443946838379
# 11
# Совпадение соответствующих feature map двух картинок = 2.1484375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9997522234916687
# 25
# Совпадение соответствующих feature map двух картинок = 4.8828125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994357824325562
# 15
# Совпадение соответствующих feature map двух картинок = 2.9296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9998053908348083
# 53
# Совпадение соответствующих feature map двух картинок = 10.3515625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9995379447937012
# 19
# Совпадение соответствующих feature map двух картинок = 3.7109375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9899108409881592
# 22
# Совпадение соответствующих feature map двух картинок = 4.296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9703150391578674
# 27
# Совпадение соответствующих feature map двух картинок = 5.2734375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9954479336738586
# 37
# Совпадение соответствующих feature map двух картинок = 7.2265625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9991155862808228
# 32
# Совпадение соответствующих feature map двух картинок = 6.25 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9998328685760498
# 55
# Совпадение соответствующих feature map двух картинок = 10.7421875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9944736361503601
# 22
# Совпадение соответствующих feature map двух картинок = 4.296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9975095987319946
# 14
# Совпадение соответствующих feature map двух картинок = 2.734375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9997115135192871
# 35
# Совпадение соответствующих feature map двух картинок = 6.8359375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9986574649810791
# 12
# Совпадение соответствующих feature map двух картинок = 2.34375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9967559576034546
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9985452890396118
# 21
# Совпадение соответствующих feature map двух картинок = 4.1015625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9949669241905212
# 24
# Совпадение соответствующих feature map двух картинок = 4.6875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9935283660888672
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9746793508529663
# 17
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9990451335906982
# 39
# Совпадение соответствующих feature map двух картинок = 7.6171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9996427297592163
# 32
# Совпадение соответствующих feature map двух картинок = 6.25 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9950432181358337
# 21
# Совпадение соответствующих feature map двух картинок = 4.1015625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9970861673355103
# 44
# Совпадение соответствующих feature map двух картинок = 8.59375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.997931182384491
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9992218017578125
# 19
# Совпадение соответствующих feature map двух картинок = 3.7109375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9993809461593628
# 18
# Совпадение соответствующих feature map двух картинок = 3.515625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9914616942405701
# 30
# Совпадение соответствующих feature map двух картинок = 5.859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9949790239334106
# 30
# Совпадение соответствующих feature map двух картинок = 5.859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9998835921287537
# 47
# Совпадение соответствующих feature map двух картинок = 9.1796875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994975328445435
# 21
# Совпадение соответствующих feature map двух картинок = 4.1015625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9997403025627136
# 31
# Совпадение соответствующих feature map двух картинок = 6.0546875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9995032548904419
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9948317408561707
# 27
# Совпадение соответствующих feature map двух картинок = 5.2734375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.999728262424469
# 57
# Совпадение соответствующих feature map двух картинок = 11.1328125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9952980875968933
# 21
# Совпадение соответствующих feature map двух картинок = 4.1015625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.999788761138916
# 30
# Совпадение соответствующих feature map двух картинок = 5.859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9993613362312317
# 42
# Совпадение соответствующих feature map двух картинок = 8.203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9906741976737976
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9996795058250427
# 17
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9977036118507385
# 9
# Совпадение соответствующих feature map двух картинок = 1.7578125 %
# 5.595703125
# 0.9954537713527679

# %%
hash = 0
cos_ = 0
path = Path("/content/hash512/images_100")
for filename in os.listdir(path):
    a, b = compare_two_pictures_px(path / filename, path / filename, model, 15)
    cos_ += float(a)
    hash += b

print(hash / 100)
print(cos_ / 100)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9989192485809326
# 74
# Совпадение соответствующих feature map двух картинок = 14.453125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9997178316116333
# 73
# Совпадение соответствующих feature map двух картинок = 14.2578125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.999129056930542
# 30
# Совпадение соответствующих feature map двух картинок = 5.859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9972987771034241
# 17
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9966977834701538
# 59
# Совпадение соответствующих feature map двух картинок = 11.5234375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9985429048538208
# 18
# Совпадение соответствующих feature map двух картинок = 3.515625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9950768947601318
# 12
# Совпадение соответствующих feature map двух картинок = 2.34375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.997585654258728
# 36
# Совпадение соответствующих feature map двух картинок = 7.03125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9875030517578125
# 19
# Совпадение соответствующих feature map двух картинок = 3.7109375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9986613988876343
# 16
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9995059370994568
# 67
# Совпадение соответствующих feature map двух картинок = 13.0859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9996660947799683
# 90
# Совпадение соответствующих feature map двух картинок = 17.578125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.998444676399231
# 25
# Совпадение соответствующих feature map двух картинок = 4.8828125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9985986948013306
# 10
# Совпадение соответствующих feature map двух картинок = 1.953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9840015172958374
# 34
# Совпадение соответствующих feature map двух картинок = 6.640625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9897373914718628
# 10
# Совпадение соответствующих feature map двух картинок = 1.953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9377204775810242
# 25
# Совпадение соответствующих feature map двух картинок = 4.8828125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.997832179069519
# 30
# Совпадение соответствующих feature map двух картинок = 5.859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9990034699440002
# 10
# Совпадение соответствующих feature map двух картинок = 1.953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9998286962509155
# 15
# Совпадение соответствующих feature map двух картинок = 2.9296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9997919797897339
# 14
# Совпадение соответствующих feature map двух картинок = 2.734375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9971263408660889
# 33
# Совпадение соответствующих feature map двух картинок = 6.4453125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9995444416999817
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994920492172241
# 65
# Совпадение соответствующих feature map двух картинок = 12.6953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9996955990791321
# 41
# Совпадение соответствующих feature map двух картинок = 8.0078125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9725321531295776
# 9
# Совпадение соответствующих feature map двух картинок = 1.7578125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9999263882637024
# 56
# Совпадение соответствующих feature map двух картинок = 10.9375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9982408881187439
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9968298673629761
# 22
# Совпадение соответствующих feature map двух картинок = 4.296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9980645775794983
# 16
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9934191107749939
# 8
# Совпадение соответствующих feature map двух картинок = 1.5625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.997968316078186
# 22
# Совпадение соответствующих feature map двух картинок = 4.296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9915013909339905
# 16
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9901489019393921
# 15
# Совпадение соответствующих feature map двух картинок = 2.9296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9993835091590881
# 76
# Совпадение соответствующих feature map двух картинок = 14.84375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9981411695480347
# 28
# Совпадение соответствующих feature map двух картинок = 5.46875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9962830543518066
# 12
# Совпадение соответствующих feature map двух картинок = 2.34375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9975326061248779
# 14
# Совпадение соответствующих feature map двух картинок = 2.734375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9996803998947144
# 35
# Совпадение соответствующих feature map двух картинок = 6.8359375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9995259046554565
# 46
# Совпадение соответствующих feature map двух картинок = 8.984375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9936887621879578
# 12
# Совпадение соответствующих feature map двух картинок = 2.34375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9848541021347046
# 9
# Совпадение соответствующих feature map двух картинок = 1.7578125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9971599578857422
# 22
# Совпадение соответствующих feature map двух картинок = 4.296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9953547120094299
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9763097763061523
# 7
# Совпадение соответствующих feature map двух картинок = 1.3671875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9766098260879517
# 17
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9944854974746704
# 16
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9991967678070068
# 44
# Совпадение соответствующих feature map двух картинок = 8.59375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9939574003219604
# 11
# Совпадение соответствующих feature map двух картинок = 2.1484375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9908028841018677
# 6
# Совпадение соответствующих feature map двух картинок = 1.171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9956027269363403
# 35
# Совпадение соответствующих feature map двух картинок = 6.8359375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.999451756477356
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.999385416507721
# 41
# Совпадение соответствующих feature map двух картинок = 8.0078125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9950070977210999
# 52
# Совпадение соответствующих feature map двух картинок = 10.15625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9970148801803589
# 31
# Совпадение соответствующих feature map двух картинок = 6.0546875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994004964828491
# 90
# Совпадение соответствующих feature map двух картинок = 17.578125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9968572854995728
# 31
# Совпадение соответствующих feature map двух картинок = 6.0546875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9980099201202393
# 16
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9990654587745667
# 41
# Совпадение соответствующих feature map двух картинок = 8.0078125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.984721839427948
# 19
# Совпадение соответствующих feature map двух картинок = 3.7109375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.983035147190094
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9997292160987854
# 25
# Совпадение соответствующих feature map двух картинок = 4.8828125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9984281063079834
# 16
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9986779093742371
# 51
# Совпадение соответствующих feature map двух картинок = 9.9609375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994521141052246
# 19
# Совпадение соответствующих feature map двух картинок = 3.7109375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9854777455329895
# 25
# Совпадение соответствующих feature map двух картинок = 4.8828125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.958344042301178
# 24
# Совпадение соответствующих feature map двух картинок = 4.6875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9954167604446411
# 37
# Совпадение соответствующих feature map двух картинок = 7.2265625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9986756443977356
# 33
# Совпадение соответствующих feature map двух картинок = 6.4453125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9998357892036438
# 55
# Совпадение соответствующих feature map двух картинок = 10.7421875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9868326783180237
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.99507075548172
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994251728057861
# 36
# Совпадение соответствующих feature map двух картинок = 7.03125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9984282851219177
# 11
# Совпадение соответствующих feature map двух картинок = 2.1484375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9903901219367981
# 17
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9984843134880066
# 21
# Совпадение соответствующих feature map двух картинок = 4.1015625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.993221640586853
# 25
# Совпадение соответствующих feature map двух картинок = 4.8828125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9932096004486084
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9680517315864563
# 15
# Совпадение соответствующих feature map двух картинок = 2.9296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9983901381492615
# 38
# Совпадение соответствующих feature map двух картинок = 7.421875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9986317157745361
# 30
# Совпадение соответствующих feature map двух картинок = 5.859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.988641619682312
# 18
# Совпадение соответствующих feature map двух картинок = 3.515625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9968829154968262
# 44
# Совпадение соответствующих feature map двух картинок = 8.59375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9978740215301514
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.998022735118866
# 18
# Совпадение соответствующих feature map двух картинок = 3.515625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9988503456115723
# 18
# Совпадение соответствующих feature map двух картинок = 3.515625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9870316386222839
# 28
# Совпадение соответствующих feature map двух картинок = 5.46875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.994552731513977
# 30
# Совпадение соответствующих feature map двух картинок = 5.859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9991239905357361
# 43
# Совпадение соответствующих feature map двух картинок = 8.3984375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9991390109062195
# 19
# Совпадение соответствующих feature map двух картинок = 3.7109375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9994524121284485
# 28
# Совпадение соответствующих feature map двух картинок = 5.46875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9987316131591797
# 17
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9945533871650696
# 27
# Совпадение соответствующих feature map двух картинок = 5.2734375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9982370734214783
# 57
# Совпадение соответствующих feature map двух картинок = 11.1328125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.993388295173645
# 20
# Совпадение соответствующих feature map двух картинок = 3.90625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9995432496070862
# 31
# Совпадение соответствующих feature map двух картинок = 6.0546875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9983106851577759
# 40
# Совпадение соответствующих feature map двух картинок = 7.8125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9906637668609619
# 13
# Совпадение соответствующих feature map двух картинок = 2.5390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9995908737182617
# 17
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9975307583808899
# 9
# Совпадение соответствующих feature map двух картинок = 1.7578125 %
# 5.46484375
# 0.9943256670236588

# %%
mkdir images_rotation_90

# %%
def compare_two_pictures_cos(path_image_one, path_image_two, model):
    image = Image.open(path_image_one).convert('RGB')
    preprocessed = preprocess(image)
    output_image_one = model(preprocessed)
    output_image_one = output_image_one.detach().cpu().numpy()

    print(output_image_one.shape)

    image = Image.open(path_image_two).convert('RGB')
    preprocessed = preprocess(image)

    output_image_two = model(preprocessed)
    output_image_two = output_image_two.detach().cpu().numpy()
    print(output_image_two.shape)

    cos = torch.nn.CosineSimilarity(dim=1)
    # print(torch.Tensor(output_image_one))
    # print(torch.Tensor(output_image_one).shape)
    cos = cos(torch.Tensor(output_image_one), torch.Tensor(output_image_two))

    # print(output_image_one[0].shape)
    # print(output_image_two[0].shape)

    print(f"Косинусное расстояние между двумя картинками равно : {cos[0]}")
    matching_hash_two_pictures(output_image_one[0], output_image_two[0])
    return float(cos[0])

# %%
path = Path("/content/hash512/images_100")
for filename in os.listdir(path):
  im = Image.open(path / filename).convert('RGB')
  im_rotate = im.rotate(90)
  im_rotate.save(Path("/content/images_rotation_90") / filename, quality=95)

# %%
cos_ = 0
path1 = Path("/content/hash512/images_100")
path2 = Path("/content/images_rotation_90")
for filename in os.listdir(path1):
    cos_ += compare_two_pictures_cos(path1 / filename, path2 / filename, model)

print(cos_ / 100)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7105175852775574
# Совпадение соответствующих feature map двух картинок = 3.3203125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7434599995613098
# Совпадение соответствующих feature map двух картинок = 4.296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6263516545295715
# Совпадение соответствующих feature map двух картинок = 0.5859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7747554779052734
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7086989283561707
# Совпадение соответствующих feature map двух картинок = 4.296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6011229157447815
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6087437272071838
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.823284924030304
# Совпадение соответствующих feature map двух картинок = 1.5625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6696018576622009
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7150906324386597
# Совпадение соответствующих feature map двух картинок = 0.5859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7283390164375305
# Совпадение соответствующих feature map двух картинок = 3.7109375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.8681788444519043
# Совпадение соответствующих feature map двух картинок = 6.25 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7536851763725281
# Совпадение соответствующих feature map двух картинок = 1.171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7958234548568726
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.517647922039032
# Совпадение соответствующих feature map двух картинок = 3.125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7224825024604797
# Совпадение соответствующих feature map двух картинок = 0.0 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.4625949561595917
# Совпадение соответствующих feature map двух картинок = 0.5859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7052544355392456
# Совпадение соответствующих feature map двух картинок = 1.171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7585355639457703
# Совпадение соответствующих feature map двух картинок = 0.0 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7442440390586853
# Совпадение соответствующих feature map двух картинок = 0.78125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.8535842299461365
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.771915853023529
# Совпадение соответствующих feature map двух картинок = 1.171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.8365759253501892
# Совпадение соответствующих feature map двух картинок = 1.171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7557151317596436
# Совпадение соответствующих feature map двух картинок = 1.3671875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6183369159698486
# Совпадение соответствующих feature map двух картинок = 0.5859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7577152848243713
# Совпадение соответствующих feature map двух картинок = 0.5859375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7880624532699585
# Совпадение соответствующих feature map двух картинок = 1.953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7130160927772522
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7198865413665771
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7018665075302124
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.8363794088363647
# Совпадение соответствующих feature map двух картинок = 1.7578125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6214292645454407
# Совпадение соответствующих feature map двух картинок = 1.171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.8063432574272156
# Совпадение соответствующих feature map двух картинок = 2.9296875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6687714457511902
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.5456988215446472
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6525258421897888
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7299779653549194
# Совпадение соответствующих feature map двух картинок = 0.9765625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6737908720970154
# Совпадение соответствующих feature map двух картинок = 2.34375 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7142748236656189
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6864117383956909
# Совпадение соответствующих feature map двух картинок = 1.171875 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6710490584373474
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7319369912147522
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7123505473136902
# Совпадение соответствующих feature map двух картинок = 0.1953125 %
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.6794089674949646
# Совпадение соответствующих feature map двух картинок = 0.390625 %
# 0.7071571722626686

# %%
def new_preprocess_other(image, width, height):
  device = torch.device('cuda')
  mean = torch.Tensor([0.485, 0.456, 0.406]).cuda()
  std = torch.Tensor([0.229, 0.224, 0.225]).cuda()

  transform = transforms.Compose([
        transforms.Resize((width, height)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
  ])

  image_transform = transform(image)

  return torch.Tensor(image_transform).unsqueeze(0).to(device)

# %%
cos_ = 0

path = Path("/content/hash512/images_100")
for filename in os.listdir(path):
  image = Image.open(path / filename).convert('RGB')
  # уменьшаем в 2 раза
  preprocessed = new_preprocess_other(image, 75, 75)
  output_image_one = model(preprocessed)
  output_image_one = output_image_one.detach().cpu().numpy()

  image = Image.open(path / filename).convert('RGB')
  preprocessed = preprocess(image)

  output_image_two = model(preprocessed)
  output_image_two = output_image_two.detach().cpu().numpy()

  cos = torch.nn.CosineSimilarity(dim=1)
  cos = cos(torch.Tensor(output_image_one), torch.Tensor(output_image_two))
  print(f"Косинусное расстояние между двумя картинками равно : {cos[0]}")
  cos_ += float(cos[0])

print(cos_ / 100)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.6904900074005127
# Косинусное расстояние между двумя картинками равно : 0.6649866104125977
# Косинусное расстояние между двумя картинками равно : 0.6687912940979004
# Косинусное расстояние между двумя картинками равно : 0.6338293552398682
# Косинусное расстояние между двумя картинками равно : 0.5178884267807007
# Косинусное расстояние между двумя картинками равно : 0.637270450592041
# Косинусное расстояние между двумя картинками равно : 0.7112370729446411
# Косинусное расстояние между двумя картинками равно : 0.6761659979820251
# Косинусное расстояние между двумя картинками равно : 0.719896137714386
# Косинусное расстояние между двумя картинками равно : 0.6506193280220032
# Косинусное расстояние между двумя картинками равно : 0.737788200378418
# Косинусное расстояние между двумя картинками равно : 0.6083250641822815
# Косинусное расстояние между двумя картинками равно : 0.63172847032547
# Косинусное расстояние между двумя картинками равно : 0.7319628000259399
# Косинусное расстояние между двумя картинками равно : 0.6770263910293579
# Косинусное расстояние между двумя картинками равно : 0.6751714944839478
# Косинусное расстояние между двумя картинками равно : 0.4851751923561096
# Косинусное расстояние между двумя картинками равно : 0.7749066948890686
# Косинусное расстояние между двумя картинками равно : 0.6160170435905457
# Косинусное расстояние между двумя картинками равно : 0.5633865594863892
# Косинусное расстояние между двумя картинками равно : 0.6907849907875061
# Косинусное расстояние между двумя картинками равно : 0.7630999684333801
# Косинусное расстояние между двумя картинками равно : 0.6962015628814697
# Косинусное расстояние между двумя картинками равно : 0.7180740237236023
# Косинусное расстояние между двумя картинками равно : 0.5959658026695251
# Косинусное расстояние между двумя картинками равно : 0.5475687384605408
# Косинусное расстояние между двумя картинками равно : 0.5377447605133057
# Косинусное расстояние между двумя картинками равно : 0.7753429412841797
# Косинусное расстояние между двумя картинками равно : 0.6649326682090759
# Косинусное расстояние между двумя картинками равно : 0.7118595838546753
# Косинусное расстояние между двумя картинками равно : 0.7330539226531982
# Косинусное расстояние между двумя картинками равно : 0.6916272640228271
# Косинусное расстояние между двумя картинками равно : 0.6871289610862732
# Косинусное расстояние между двумя картинками равно : 0.6181023120880127
# Косинусное расстояние между двумя картинками равно : 0.6674242615699768
# Косинусное расстояние между двумя картинками равно : 0.716419517993927
# Косинусное расстояние между двумя картинками равно : 0.787834107875824
# Косинусное расстояние между двумя картинками равно : 0.6980286836624146
# Косинусное расстояние между двумя картинками равно : 0.6518963575363159
# Косинусное расстояние между двумя картинками равно : 0.6820144653320312
# Косинусное расстояние между двумя картинками равно : 0.7953966856002808
# Косинусное расстояние между двумя картинками равно : 0.7014358639717102
# Косинусное расстояние между двумя картинками равно : 0.7187966108322144
# Косинусное расстояние между двумя картинками равно : 0.6265556216239929
# Косинусное расстояние между двумя картинками равно : 0.7458140850067139
# Косинусное расстояние между двумя картинками равно : 0.672160804271698
# Косинусное расстояние между двумя картинками равно : 0.7371015548706055
# Косинусное расстояние между двумя картинками равно : 0.654841423034668
# 0.6637083792686462

# %%
cos_ = 0

path = Path("/content/hash512/images_100")
for filename in os.listdir(path):
  image = Image.open(path / filename).convert('RGB')
  # увеличиваем в 3 раза
  preprocessed = new_preprocess_other(image, 450, 450)
  output_image_one = model(preprocessed)
  output_image_one = output_image_one.detach().cpu().numpy()

  image = Image.open(path / filename).convert('RGB')
  preprocessed = preprocess(image)

  output_image_two = model(preprocessed)
  output_image_two = output_image_two.detach().cpu().numpy()

  cos = torch.nn.CosineSimilarity(dim=1)
  cos = cos(torch.Tensor(output_image_one), torch.Tensor(output_image_two))
  print(f"Косинусное расстояние между двумя картинками равно : {cos[0]}")
  cos_ += float(cos[0])

print(cos_ / 100)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.6744785904884338
# Косинусное расстояние между двумя картинками равно : 0.7703930735588074
# Косинусное расстояние между двумя картинками равно : 0.7595457434654236
# Косинусное расстояние между двумя картинками равно : 0.7971145510673523
# Косинусное расстояние между двумя картинками равно : 0.7955452799797058
# Косинусное расстояние между двумя картинками равно : 0.7611444592475891
# Косинусное расстояние между двумя картинками равно : 0.8296974897384644
# Косинусное расстояние между двумя картинками равно : 0.7758249640464783
# Косинусное расстояние между двумя картинками равно : 0.753829836845398
# Косинусное расстояние между двумя картинками равно : 0.761905312538147
# Косинусное расстояние между двумя картинками равно : 0.6724218130111694
# Косинусное расстояние между двумя картинками равно : 0.7024937272071838
# Косинусное расстояние между двумя картинками равно : 0.7383933067321777
# Косинусное расстояние между двумя картинками равно : 0.8108483552932739
# Косинусное расстояние между двумя картинками равно : 0.8224639892578125
# Косинусное расстояние между двумя картинками равно : 0.8384193181991577
# Косинусное расстояние между двумя картинками равно : 0.7238824367523193
# Косинусное расстояние между двумя картинками равно : 0.8015947341918945
# Косинусное расстояние между двумя картинками равно : 0.7964937686920166
# Косинусное расстояние между двумя картинками равно : 0.76072758436203
# Косинусное расстояние между двумя картинками равно : 0.7483646869659424
# Косинусное расстояние между двумя картинками равно : 0.7853525876998901
# Косинусное расстояние между двумя картинками равно : 0.7665542364120483
# Косинусное расстояние между двумя картинками равно : 0.7802930474281311
# Косинусное расстояние между двумя картинками равно : 0.754218578338623
# Косинусное расстояние между двумя картинками равно : 0.7568565607070923
# Косинусное расстояние между двумя картинками равно : 0.7743375301361084
# Косинусное расстояние между двумя картинками равно : 0.7624896764755249
# Косинусное расстояние между двумя картинками равно : 0.7893978357315063
# Косинусное расстояние между двумя картинками равно : 0.7859408259391785
# Косинусное расстояние между двумя картинками равно : 0.7229340076446533
# Косинусное расстояние между двумя картинками равно : 0.7759520411491394
# Косинусное расстояние между двумя картинками равно : 0.7533301711082458
# Косинусное расстояние между двумя картинками равно : 0.7405965328216553
# Косинусное расстояние между двумя картинками равно : 0.7603090405464172
# Косинусное расстояние между двумя картинками равно : 0.8101571798324585
# Косинусное расстояние между двумя картинками равно : 0.8095335960388184
# Косинусное расстояние между двумя картинками равно : 0.7667291164398193
# Косинусное расстояние между двумя картинками равно : 0.7948014140129089
# Косинусное расстояние между двумя картинками равно : 0.761566698551178
# Косинусное расстояние между двумя картинками равно : 0.8037687540054321
# Косинусное расстояние между двумя картинками равно : 0.8014328479766846
# Косинусное расстояние между двумя картинками равно : 0.796882152557373
# Косинусное расстояние между двумя картинками равно : 0.7427852749824524
# Косинусное расстояние между двумя картинками равно : 0.8268616199493408
# Косинусное расстояние между двумя картинками равно : 0.7653160691261292
# Косинусное расстояние между двумя картинками равно : 0.7689214944839478
# Косинусное расстояние между двумя картинками равно : 0.7925054430961609
# 0.7768616271018982

# %%
# две картинки одинаковые но одна увеличенная без resize
compare_two_pictures('/content/sample_data/9.png', '/content/sample_data/9.big.png', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9297694563865662
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две картинки одинаковые но одна увеличенная с resize
compare_two_pictures_other1('/content/sample_data/9.png', '/content/sample_data/9.big.png', model)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.9998390078544617
# Совпадение соответствующих feature map двух картинок = 0.9765625 %

# %%
# две картинки одинаковые но одна чернобелая без resize
compare_two_pictures('/content/sample_data/9.png', '/content/sample_data/9black.png', model)
# Out:
# (1, 512)
# torch.Size([1, 3, 438, 427])
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9763650894165039
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две картинки одинаковые но одна чернобелая с resize
compare_two_pictures_other1('/content/sample_data/9.png', '/content/sample_data/9black.png', model)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.9512357115745544
# Совпадение соответствующих feature map двух картинок = 0.390625 %

# %%
# сравниваем две одинаковые картинки одна с resize другая без
compare_two_pictures_other('/content/sample_data/9.png', '/content/sample_data/9.png', model)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.9161692261695862
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# сравниваем сканы двух разных документов
compare_two_pictures('/content/sample_data/скан1.jpg', '/content/sample_data/скан2.jpg', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9254958033561707
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
compare_two_pictures('/content/sample_data/скан1.jpg', '/content/sample_data/VqCifTlKe-A.jpg', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.8215687274932861
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две одинаковые картинки только одна имеет другой контраст
compare_two_pictures('sample_data/9.png', 'sample_data/9gl.png', model)
# Out:
# (1, 512)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-fe0149c8270c> in <cell line: 2>()
#       1 # две одинаковые картинки только одна имеет другой контраст
# ----> 2 compare_two_pictures('sample_data/9.png', 'sample_data/9gl.png', model)
#
# <ipython-input-6-8bc21b8b4f65> in compare_two_pictures(path_image_one, path_image_two, model, change_one_pixel)
#       7     print(output_image_one.shape)
#       8
# ----> 9     image = Image.open(path_image_two).convert('RGB')
#      10     preprocessed = preprocess(image)
#      11
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_data/9gl.png'

# %%
# две одинаковые картинки только одна имеет другой контраст и поворот
compare_two_pictures('sample_data/9.png', 'sample_data/9gl_pov.png', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.7844823002815247
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две одинаковые картинки только одна черно-белая
compare_two_pictures('sample_data/9.png', 'sample_data/9black.png', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9986156821250916
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две одинаковые картинки только одна черно-белая
compare_two_pictures('/content/sample_data/красная площадь2.jpg', '/content/sample_data/красная площадь2_black.jpg', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9594357013702393
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
compare_two_pictures('/content/sample_data/красная площадь1.jpg', '/content/sample_data/красная площадь2_black.jpg', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.8560234904289246
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две одинаковые картинки только одна перевернута
compare_two_pictures('sample_data/9.png', 'sample_data/m_9.png', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9530755877494812
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две одинаковые картинки только одна растянута
compare_two_pictures('sample_data/9.png', '/content/sample_data/9.big.png', model)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9297694563865662
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# две одинаковые картинки только в одной из них изменен 1 канал
compare_two_pictures('sample_data/9.png', 'sample_data/9.png', model, change_one_pixel=True)
# Out:
# (1, 512)
# (1, 512)
# Косинусное расстояние между двумя картинками равно : 0.9999993443489075
# Совпадение соответствующих feature map двух картинок = 0.78125 %

# %%
# две одинаковые картинки но под разными ракурсами
compare_two_pictures('sample_data/VqCifTlKe-A.jpg', 'sample_data/uKF9WyvZlbE.jpg', model)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.9211031794548035
# Совпадение соответствующих feature map двух картинок = 0.1953125 %

# %%
# две фотографии с красной площадью в разное время суток и с разным ракурсом
compare_two_pictures('sample_data/красная площадь1.jpg', 'sample_data/красная площадь2.jpg', model)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.7922313213348389
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# сравнение картинок с собакой и кошкой
compare_two_pictures('sample_data/cat.jpg', 'sample_data/dog.jpg', model)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.5034276247024536
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
# сравнение картинок с красной площадью и кошкой
compare_two_pictures('sample_data/cat.jpg', 'sample_data/красная площадь1.jpg', model)
# Out:
# Косинусное расстояние между двумя картинками равно : 0.48150527477264404
# Совпадение соответствующих feature map двух картинок = 0.0 %

# %%
compare_two_pictures('sample_data/красная площадь1.jpg', 'sample_data/красная площадь1.jpg', model)
# Out:
# (512,)
# (512,)
# Косинусное расстояние между двумя картинками равно : 0.9999998807907104
# Совпадение соответствующих feature map двух картинок = 100.0 %

# %%
# !git clone https://github.com/laxmimerit/dog-cat-full-dataset.git
# Out:
# Cloning into 'dog-cat-full-dataset'...
# remote: Enumerating objects: 25027, done.
# remote: Total 25027 (delta 0), reused 0 (delta 0), pack-reused 25027
# Receiving objects: 100% (25027/25027), 541.62 MiB | 24.84 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Updating files: 100% (25001/25001), done.

# %%
path_dataset = Path("dog-cat-full-dataset/data/train")

# %%
class BinaryClassification(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super().__init__()
        self.model = torch.nn.Sequential(torch.nn.Linear(input_size, 64),
                               torch.nn.BatchNorm1d(64),
                               torch.nn.Dropout1d(0.2),
                               torch.nn.ReLU(),
                               torch.nn.Linear(64, 16),
                               torch.nn.BatchNorm1d(16),
                               torch.nn.Dropout1d(0.2),
                               torch.nn.ReLU(),
                               torch.nn.Linear(16, num_classes),
                               #torch.nn.Sigmoid())
                               torch.nn.Softmax())

    def get_weights(self):
        return self.weight

    def forward(self,x):
        x = self.model(x)
        return x

    def eval(self):
        self.model.eval()

# %%
class CatDogDataset(Dataset):
    def __init__(self, path: Path, coder: ImageEncoder):
        self.path_dataset = path
        self.coder = coder
        self.path_dirs_images = [path_dir for path_dir in path_dataset.iterdir() if path_dir.is_dir()]
        self.path_images = [path_image for path_dir_images in self.path_dirs_images for path_image in path_dir_images.iterdir()]
        self.path_images = self.path_images[:500] + self.path_images[-500:]

    def __len__(self):
        return len(self.path_images)

    def __getitem__(self, index):
        image = Image.open(self.path_images[index])
        preprocessed = preprocess(image)
        output = self.coder(preprocessed)
        output = output.detach().cpu().numpy()
        image_feature_map512 = output[0]

        target = torch.zeros(2)

        if "dog" in self.path_images[index].stem:
            target[0] = 1
        else:
            target[1] = 1

        return image_feature_map512, target

# %%
dataset = CatDogDataset(path_dataset, model)
trainloader = DataLoader(dataset, batch_size=20, shuffle=True)
model_classification = BinaryClassification(512, 2048, 2)
optimizer = torch.optim.Adam(model_classification.parameters(), lr=0.001)
loss = torch.nn.CrossEntropyLoss()

# %%
def train_one_epoch(epoch, trainloader, optimizer, model, criterion, dataset):
    correct = 0
    epoch_loss = 0.0
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


    for i, data in enumerate(trainloader, 0):
        print(f"Батч № {i+1}")
        x, y = data
        # print(y)
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        model = model.to(device)
        outputs = model(x)
        loss = criterion(outputs, y)
        loss.backward()
        epoch_loss += loss.item()
        _, predicted = outputs.max(1)

        for j, i in enumerate(y.detach().cpu().numpy()):
          if list(i) == list([1.0, 0.0]):
              y_ = 0
          else:
              y_ = 1
          if y_ == int(predicted[j]):
              correct += 1

        optimizer.step()

    print(f'TRAIN [{epoch + 1}] loss: {epoch_loss / 50:.3f} accuracy: {correct / len(trainloader.dataset):.3f}')

# %%
for epoch in range(50):
    train_one_epoch(epoch, trainloader, optimizer, model_classification, loss, dataset)
# Out:
# Батч № 1
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py:204: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [1] loss: 0.549 accuracy: 0.773
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [2] loss: 0.496 accuracy: 0.830
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [3] loss: 0.471 accuracy: 0.841
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [4] loss: 0.472 accuracy: 0.807
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [5] loss: 0.458 accuracy: 0.837
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [6] loss: 0.458 accuracy: 0.820
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [7] loss: 0.464 accuracy: 0.830
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [8] loss: 0.455 accuracy: 0.839
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [9] loss: 0.444 accuracy: 0.849
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [10] loss: 0.445 accuracy: 0.840
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-22597ba21759> in <module>
#       1 for epoch in range(50):
# ----> 2     train_one_epoch(epoch, trainloader, optimizer, model_classification, loss, dataset)
#
# <ipython-input-12-66baa00f3c7a> in train_one_epoch(epoch, trainloader, optimizer, model, criterion, dataset)
#       5
#       6
# ----> 7     for i, data in enumerate(trainloader, 0):
#       8         print(f"Батч № {i+1}")
#       9         x, y = data
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# <ipython-input-10-0be3004171aa> in __getitem__(self, index)
#      13         image = Image.open(self.path_images[index])
#      14         preprocessed = preprocess(image)
# ---> 15         output = self.coder(preprocessed)
#      16         output = output.detach().cpu().numpy()
#      17         image_feature_map512 = output[0]
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-2-f9fe2d7b1783> in forward(self, x)
#      10
#      11     def forward(self, x):
# ---> 12         x = self.encoder(x)
#      13         return x
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torchvision/models/resnet.py in forward(self, x)
#      90         identity = x
#      91
# ---> 92         out = self.conv1(x)
#      93         out = self.bn1(out)
#      94         out = self.relu(out)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:

# %%
image = Image.open("dog-cat-full-dataset/data/test/dogs/dog.10025.jpg")
preprocessed = preprocess(image)
output = model(preprocessed)
output = output.detach().cpu().numpy()

# %%
model_classification.eval()
model_classification(torch.Tensor(output).cuda())
# Out:
# tensor([[0.9407, 0.0593]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %%
# на выходе одно значение
class BinaryClassification(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super().__init__()
        self.model = torch.nn.Sequential(torch.nn.Linear(input_size, 64),
                               torch.nn.BatchNorm1d(64),
                               torch.nn.Dropout1d(0.2),
                               torch.nn.ReLU(),
                               torch.nn.Linear(64, 16),
                               torch.nn.BatchNorm1d(16),
                               torch.nn.Dropout1d(0.2),
                               torch.nn.ReLU(),
                               torch.nn.Linear(16, num_classes),
                               torch.nn.Sigmoid())

    def get_weights(self):
        return self.weight

    def forward(self, x):
        x = self.model(x)
        return x

    def eval(self):
        self.model.eval()

# %%
class CatDogDataset(Dataset):
    def __init__(self, path: Path, coder: ImageEncoder):
        self.path_dataset = path
        self.coder = coder
        self.path_dirs_images = [path_dir for path_dir in path_dataset.iterdir() if path_dir.is_dir()]
        self.path_images = [path_image for path_dir_images in self.path_dirs_images for path_image in path_dir_images.iterdir()]
        self.path_images = self.path_images[:500] + self.path_images[-500:]

    def __len__(self):
        return len(self.path_images)

    def __getitem__(self, index):
        image = Image.open(self.path_images[index])
        preprocessed = preprocess(image)
        output = self.coder(preprocessed)
        output = output.detach().cpu().numpy()
        image_feature_map512 = output[0]

        if "dog" in self.path_images[index].stem:
            target = 0
        else:
            target = 1

        return image_feature_map512, np.float32(target)

# %%
dataset = CatDogDataset(path_dataset, model)
trainloader = DataLoader(dataset, batch_size=20, shuffle=True)
model_classification = BinaryClassification(512, 2048, 1)
optimizer = torch.optim.Adam(model_classification.parameters(), lr=0.001)
loss = torch.nn.BCELoss()

# %%
def train_one_epoch(epoch, trainloader, optimizer, model, criterion, dataset):
    correct = 0
    epoch_loss = 0.0
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


    for i, data in enumerate(trainloader, 0):
        print(f"Батч № {i+1}")
        x, y = data
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        model = model.to(device)
        outputs = model(x)
        loss = criterion(outputs, y.unsqueeze(-1))
        loss.backward()
        epoch_loss += loss.item()
        predicted = outputs

        for target, pred in zip(y.detach().cpu().numpy(), predicted.detach().cpu().numpy()):
            if float(pred) > 0.7:
                pred = 1
            else:
                pred = 0

            if pred == int(target):
                correct += 1

        optimizer.step()

    print(f'TRAIN [{epoch + 1}] loss: {epoch_loss / 50:.3f} accuracy: {correct / len(trainloader.dataset):.3f}')

# %%
for epoch in range(50):
    train_one_epoch(epoch, trainloader, optimizer, model_classification, loss, dataset)
# Out:
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [1] loss: 0.419 accuracy: 0.736
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [2] loss: 0.341 accuracy: 0.795
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [3] loss: 0.313 accuracy: 0.808
# Батч № 1
# Батч № 2
# Батч № 3
# Батч № 4
# Батч № 5
# Батч № 6
# Батч № 7
# Батч № 8
# Батч № 9
# Батч № 10
# Батч № 11
# Батч № 12
# Батч № 13
# Батч № 14
# Батч № 15
# Батч № 16
# Батч № 17
# Батч № 18
# Батч № 19
# Батч № 20
# Батч № 21
# Батч № 22
# Батч № 23
# Батч № 24
# Батч № 25
# Батч № 26
# Батч № 27
# Батч № 28
# Батч № 29
# Батч № 30
# Батч № 31
# Батч № 32
# Батч № 33
# Батч № 34
# Батч № 35
# Батч № 36
# Батч № 37
# Батч № 38
# Батч № 39
# Батч № 40
# Батч № 41
# Батч № 42
# Батч № 43
# Батч № 44
# Батч № 45
# Батч № 46
# Батч № 47
# Батч № 48
# Батч № 49
# Батч № 50
# TRAIN [4] loss: 0.285 accuracy: 0.829
# Батч № 1
# Батч № 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-22597ba21759> in <module>
#       1 for epoch in range(50):
# ----> 2     train_one_epoch(epoch, trainloader, optimizer, model_classification, loss, dataset)
#
# <ipython-input-48-5ec91002e860> in train_one_epoch(epoch, trainloader, optimizer, model, criterion, dataset)
#       5
#       6
# ----> 7     for i, data in enumerate(trainloader, 0):
#       8         print(f"Батч № {i+1}")
#       9         x, y = data
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# <ipython-input-46-d0669efe87af> in __getitem__(self, index)
#      11
#      12     def __getitem__(self, index):
# ---> 13         image = Image.open(self.path_images[index])
#      14         preprocessed = preprocess(image)
#      15         output = self.coder(preprocessed)
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in open(fp, mode)
#    2879         return None
#    2880
# -> 2881     im = _open_core(fp, filename, prefix)
#    2882
#    2883     if im is None:
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in _open_core(fp, filename, prefix)
#    2865                 elif result:
#    2866                     fp.seek(0)
# -> 2867                     im = factory(fp, filename)
#    2868                     _decompression_bomb_check(im.size)
#    2869                     return im
#
# /usr/local/lib/python3.8/dist-packages/PIL/JpegImagePlugin.py in jpeg_factory(fp, filename)
#     777 # Factory for making JPEG and MPO instances
#     778 def jpeg_factory(fp=None, filename=None):
# --> 779     im = JpegImageFile(fp, filename)
#     780     try:
#     781         mpheader = im._getmp()
#
# /usr/local/lib/python3.8/dist-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     105         try:
#     106             try:
# --> 107                 self._open()
#     108             except (
#     109                 IndexError,  # end of data
#
# /usr/local/lib/python3.8/dist-packages/PIL/JpegImagePlugin.py in _open(self)
#     374                     if self.mode == "CMYK":
#     375                         rawmode = "CMYK;I"  # assume adobe conventions
# --> 376                     self.tile = [("jpeg", (0, 0) + self.size, 0, (rawmode, ""))]
#     377                     # self.__offset = self.fp.tell()
#     378                     break
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in size(self)
#     548         return self.size[1]
#     549
# --> 550     @property
#     551     def size(self):
#     552         return self._size
#
# KeyboardInterrupt:
